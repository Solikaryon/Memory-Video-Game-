# %%
# DECLARACIÓN DE VARIABLES
# Ejemplo:
# X = JUGADOR


# Diccionario de top jugadores
global_ranking = dict()

# Diccionario de partidas
jugadores = dict()

# %%
jugadores = dict()
i=0
puntaje = 0
VIDAS = 5
# Proyecto Final Equipo Escuadron lobo Xforce 69420 Doge
# Juego de Memoria
# Autores:
  # Monjaraz Briseño Luis Fernando
  # Navarro Hernandez Diego Levy Absalon
  # Navarro Rodriguez Damian
  # Necoechea Solorzano Miguel Angel
  # Nieves Toscano Oscar Yahir
  # Olague Renteria Jorge Alexis Yahir

import time
import os
from IPython.display import clear_output

# Añade un nuevo jugador a la partida actual, con una lista de puntuaciones
# Esta sera igual a 0, Si el jugador ya existe, no sera agregado, ademas de
# volver a pedirle a un usuario.
# Hecho por Olague Renteria Jorge Alexis Yahir y Miguel Necoechea.
def registro():
    clear_output()
    while True:
        respuesta = input("Desea registrar a alguien Si/No: ")
        respuesta = respuesta.upper()
        if respuesta == "SI":
            nombre_de_registro = input("Ingrese el nombre del nuevo jugador: ")
            if nombre_de_registro in jugadores.keys():
                print("\033[0;31m"+"Jugador ya existente.\nIntente de nuevo")
                input("Presiona ENTER para continuar...")

                registro()
                break
            else:
                jugadores.setdefault(nombre_de_registro, [0])
                print("\033[0;32m"+"Jugador añadido de forma exitosa.")
                input("Presiona ENTER para continuar...")
                os.system("cls")
        elif respuesta == "NO":
            print("Ha terminado el registro")
            time.sleep(3)
            clear_output()
            break
        else:
            print("\033[0;31m"+"Respuesta no valida intente de nuevo")


def play(VIDAS, puntaje): # Función de "jugar".
  if VIDAS == 0:
    print("Has perdido.")
    time.sleep(3)
    clear_output()
    main_menu()
  elif VIDAS > 0:
    clear_output()
    LF1 = ["Hola", "Python", "Computación", "Mundo", "Programar"]
    LF1R = []
    LF2 = ["Perro", "Gato", "Zorro", "León", "Elefante"]
    LF2R = []
    LM3 = ["Rojo", "Marrón", "Violeta", "Turquesa", "Rubí"]
    LM3R = []
    LM4 = ["!", "%", "#", "=", "$"]
    LM4R = []
    LD5 = ["Hipopotomonstrosesquipedaliofobia", "Euroescepticismo", "Desoxirribonucleótido", "Otorrinolaringológico", "Faringoamigdalitis"]
    print("Cargando...")
    print("Tienes {} vidas".format(VIDAS))
    time.sleep(0.5)
    nj = input("Ingrese el nombre de su usuario: ")
    if nj not in jugadores:
      registro()
    elif nj in jugadores:
      np = dict()
      np = {nj}
  #Inicia primera ronda
      clear_output()
      print("Tienes 60 segundos para memorizar...")
      time.sleep(0.5)
      print("Nivel 1:",LF1)
      time.sleep(60)
      clear_output()
      j = 5
      while j != 0:
        r = str(input("Ingrese los elementos en orden de la lista anteriormente mostrada: "))
        LF1R.append(r)
        j -= 1
      if LF1 != LF1R:
        print("Te equivocaste")
        VIDAS = VIDAS - 1
        play(VIDAS, puntaje)
      elif LF1 == LF1R:
        print("Es correcto")
        puntaje = puntaje + 10
        time.sleep(1)
        clear_output()
    #Inicia segunda ronda
        print("Tienes 60 segundos para memorizar...")
        time.sleep(0.5)
        print("Nivel 2:",LF2)
        time.sleep(60)
        clear_output()
        j = 5
        while j != 0:
          r = str(input("Ingrese los elementos en orden de la lista anteriormente mostrada: "))
          LF1R.append(r)
          j -= 1
        if LF2 != LF2R:
          print("Te equivocaste")
          VIDAS = VIDAS - 1
          play(VIDAS, puntaje)
        elif LF2 == LF2R:
          print("Es correcto")
          puntaje = puntaje + 10
          time.sleep(1)
          clear_output()
  #Inicia tercera ronda
          print("Tienes 45 segundos para memorizar...")
          time.sleep(0.5)
          print("Nivel 3:",LM3)
          time.sleep(45)
          clear_output()
          j = 5
          while j != 0:
            r = str(input("Ingrese los elementos en orden de la lista anteriormente mostrada: "))
            LM3R.append(r)
            j -= 1
          if LM3 != LM3R:
            print("Te equivocaste")
            VIDAS = VIDAS - 1
            play(VIDAS, puntaje)
          elif LM3 == LM3R:
            print("Es correcto")
            puntaje = puntaje + 20
            time.sleep(1)
            clear_output()
  #Inicia cuarta ronda
            print("Tienes 45 segundos para memorizar...")
            time.sleep(0.5)
            print("Nivel 4:",LM4)
            time.sleep(45)
            clear_output()
            j = 5
            while j != 0:
              r = str(input("Ingrese los elementos en orden de la lista anteriormente mostrada: "))
              LM4R.append(r)
              j -= 1
            if LM4 != LM4R:
              print("Te equivocaste")
              VIDAS = VIDAS - 1
              play(VIDAS, puntaje)
            elif LM4 == LM4R:
              print("Es correcto")
              puntaje = puntaje + 20
              time.sleep(1)
              clear_output()
  #Inicia quinta ronda
              print("Tienes 30 segundos para memorizar...")
              time.sleep(0.5)
              print("Nivel 5:",LD5)
              time.sleep(30)
              clear_output()
              r = str(input("Ingrese alguno de los cinco elementos de la lista anteriormente mostrada: "))
              if r not in LD5:
                print("Te equivocaste")
                VIDAS = VIDAS - 1
                play(VIDAS, puntaje)
              elif r in LD5:
                print("Es correcto")
                puntaje = puntaje + 30
                time.sleep(1)
                clear_output()
  #Puntaje
                np[nj] = puntaje






def scores(): #Funcion de verificacion de puntuaciones

  nombre_jugador=input("Ingrese el nombre del jugador \n o escriba salir para regresar al menu: ")
  if nombre_jugador in jugadores.keys():
      print ("Hola",nombre_jugador)#Saludo al jugador
      print ("Partidas jugadas: \n")#Partidas jugadas
      print ("") #Esto es las partidas que ha jugado el usuario =)
      print ("\nRanking global:\n",global_ranking.items())
      ranking_copia=global_ranking.copy()#De aqui no se ha probado
      ranking_copia=set(ranking_lista)
      while i >= ranking_lista():
            i+=1
      for ranking_lista in range(ranking_lista,ranking_lista.len):
        print (ranking_lista)
        ranking_lista.pop()#Hasta aqui no hemos probado =)
  elif nombre_jugador=="salir":
    print("devuelta al menu")
  else:
      print ("Nombre inexistente, pruebe de nuevo\n")
      scores()



jugadores=dict()
global_ranking=dict()

#Listas de jugadores y puntos
#Historial de partidas

# El proposito del try hace resistente el programa a entradas que no sean numeros
# Mientras que el while hace que el usuario se pueda equivocar infinitas veces
# @author: Miguel Necoechea
def main_menu():
    while True:
        print("\033[0;37m"+"")
        print("Opciones disponibles")
        print("1. Registrar jugador\n2. Verificar puntuaciones")
        print("3. Jugar\n4. Salir")
        was_answered = False
        while not was_answered:
            try:
                option = int(input("\nIngrese la opcion deseada: "))
                was_answered = True
                if option < 1 or option > 4:
                    was_answered = False
                    print("Opcion fuera de rango\n")
            except:
                print("Ingrese un numero por favor.\n")
        if option == 1: # Aqui va la funcion de registro
            #Neco
            #Alexis
            registro()
        elif option == 2: # Aqui va la funcion para verificar puntuaciones
            #Damian
            #Oscar
            scores()
            pass
        elif option == 3: # Aqui va la funcion de jugar
            #Diego Levy
            #Luis Fernando
            play(VIDAS, puntaje)
        elif option == 4: # Parte para salir
            print("Que tenga un buen dia!")
            break




print("--INICIO--")
main_menu()
# Out:
# Opciones disponibles
# 1. Registrar jugador
# 2. Verificar puntuaciones
# 3. Jugar
# 4. Salir
# Que tenga un buen dia!
